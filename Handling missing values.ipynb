# %%
# libraries used

import pandas as pd
import numpy as np

# read the dataset file

sf_permits = pd.read_csv("Building_Permits.csv")

# set seed for reproducibility

np.random.seed(0)
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# looking at the dataset there are few rows missing data already
sf_permits.sample(5)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 60635   201409105988            3  additions alterations or repairs
# 110430  201601046309            8            otc alterations permit
# 165042  201707212672            3  additions alterations or repairs
# 79200   201503171100            8            otc alterations permit
# 76487   201502208860            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 60635            09/10/2014  0479   027           1356                  NaN
# 110430           01/04/2016  1276  001H            202                  NaN
# 165042           07/21/2017  3622   004            818                  NaN
# 79200            03/17/2015  1509   009            547                  NaN
# 76487            02/20/2015  1923   023           1662                  NaN
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# ...

# %%
# getting the number of missing data points per column
missing_values = sf_permits.isnull().sum()

# looking at number of missing points in the first 10 columns
missing_values[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %% [markdown]
# That seems a lot of missing data. It will be helpful to see what percentage of values in our dataset are missing

# %%
total_cells = np.product(sf_permits.shape)
total_missing = missing_values.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 26.26002315058403

# %% [markdown]
# Wow more than quarter of the cells in the dataset are empty. Is this value msising because it wasn't recorded or because it doesn't exist ?

# %%
missing_values[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
# remove all the rows that contain a missing value
sf_permits.dropna()
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []
#
# [0 rows x 43 columns]

# %% [markdown]
# It looks like that's removed all our data. This is because every row in our dataset has a missing value. Now we will have to remove all the columns that have atleast one missing value

# %%
# remove all columns with atleast one missing value
columns_with_na = sf_permits.dropna(axis=1)
columns_with_na.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# ...

# %%
# comparing the two dataset to check how much data we lost 
print("Columns in original dataset: %d \n" % sf_permits.shape[1])
print("Columns with na's dropped: %d" % columns_with_na.shape[1])
# Out:
# Columns in original dataset: 43
#
# Columns with na's dropped: 12

# %%
sf_permits.head(5)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
subset = sf_permits.loc[:, 'Permit Number':'Record ID'].head()
subset
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
# replacing na's with 0
subset.fillna(0)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number  Street Number Suffix  \
# 0           05/06/2015  0326  023            140                     0
# 1           04/19/2016  0306  007            440                     0
# 2           05/27/2016  0595  203           1647                     0
# 3           11/07/2016  0156  011           1230                     0
# 4           11/28/2016  0342  001            950                     0
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
# replace all NA's the value that comes directly after it in the same column, 
# then replace all the reamining na's with 0
sf_permits.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %% [markdown]
# Fillig missing value is also know as imputation. So either you can fill it with "0" or else you can use the values that are below and above of the missing values.
#
# THANK YOU.
